# %%
mix = [1,"text",3.29]
mix = [1,"text",3.29]
print(mix[0])
print(mix[1])
print(mix[2])
# Out:
# 1
# text
# 3.29

# %%
# Indexing
x = ("variable")
print(x[0])
print(x[1])
print(x[2])
print(x[3])
print(x[4])
print(x[5])
print(x[6])
print(x[7])
# Out:
# v
# a
# r
# i
# a
# b
# l
# e

# %%
mix = ["white","black",3.1,41]
print(mix[0])
print(mix[1])
print(mix[2])
print(mix[3])
# Out:
# white
# black
# 3.1
# 41

# %%
mix = ["white","black",3.1,41]
print(mix[-1])
print(mix[-2])
print(mix[-3])
print(mix[-4])
# Out:
# 41
# 3.1
# black
# white

# %%
text = "we are learning python string operations"
print(text[0:2])
print(text[3:6])
print(text[7:15])
print(text[16:22])
print(text[23:29])
print(text[30:40])
# Out:
# we
# are
# learning
# python
# string
# operations

# %%
text = "we are learning python string operations"
print(text[-40:-38])
print(text[-37:-34])
print(text[-33:-25])
print(text[-24:-18])
print(text[-17:-11])
print(text[-10:])
# Out:
# we
# are
# learning
# python
# string
# operations
